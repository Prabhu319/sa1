# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('FuelConsumption.csv')
plt.scatter(df['CYLINDERS'],df['CO2EMISSIONS'],color='g')
plt.title('CO2 EMISSIONS VS CYLINDERS')
plt.xlabel('CYLINDERS')
plt.ylabel('CO2 EMISSIONS')
plt.show()
